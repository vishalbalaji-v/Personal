# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalbalaji-v/Personal/blob/main/Parsing%20Spar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import json
import re
import requests
from bs4 import BeautifulSoup
from collections import OrderedDict

# %%
url = requests.get('https://www.sparindia.com/')

# %%
soup = BeautifulSoup(url.text,'html.parser')

# %%
shop = soup.find_all('div',attrs={'class':'accordion'})

# %%
headers = shop[0].find_all('div',attrs={'class':'accordion'})

# %%
xx = []
for i in range(200):
  try:
    xx.append(shop[i].find_all('div',attrs={'class':'acc-header'})[0].text.strip())
  except:
    break

# %%
xx
# Out:
# ['Easybuy',
#  'Men',
#  'Women',
#  'Kids',
#  'Fresh Vegetables',
#  'Cut Vegetables & Salads',
#  'Fresh Fruits',
#  'Exotic Fruits & Vegetables',
#  'Gardening',
#  'Festival Items',
#  'Cooking Paste',
#  'Dals & Pulses',
#  'Diabetic',
#  'Dry Fruits',
#  'Edible Oil & Ghee',
#  'Flours & Sooji',
#  'Masala & Spices',
#  'Organic',
#  'Organic Dry Fruits',
#  'Organic Edible Oil / Fats',
#  'Organic Flours',
#  'Organic Grains',
#  'Organic Pulses',
#  'Organic Spices',
#  'Organic Sugar/Jaggery/Salt',
#  'Ready Mixes',
#  'Rice, Wheat & Other Grains',
#  'Salt, Sugar & Jaggery',
#  'Canned & Tinned Food',
#  'Chicken',
#  'Eggs',
#  'Fish & SeaFood',
#  'Frozen Non Veg',
#  'Lamb',
#  'Meat - Delicatessen',
#  'Other Meat',
#  'Dairy Products',
#  'Frozen Veg',
#  'Frozen Non Veg',
#  'Ice Cream & Desserts',
#  'Bakery & Breads',
#  'Dairy Whiteners',
#  'Drink Mixes',
#  'Fruit Juices & Drinks',
#  'Health Drinks',
#  'Mineral Water & Soda',
#  'Organic',
#  'Soft Drinks',
# ...

# %%
xyz = OrderedDict()
aa = xx
for i in aa:
  for j in headers:
    if j.find_all('div',attrs={'class':'acc-header'})[0].text.strip() == i:
      ff = []
      for k in j.find_all('li'):
        ff.append(k.text.strip())
      xyz[i] = ff

# %%
xyz
# Out:
# OrderedDict([('Men',
#               ['Tees', 'Shirts', 'Bottoms and Denims', 'Active & Loungewear']),
#              ('Women', ['Indian wear', 'Western Wear', 'Active wear']),
#              ('Kids',
#               ['Boys 2 - 8 Years',
#                'Boys 8 - 14 Years',
#                'Girls 2 - 8 Years',
#                'Girls 8 - 14 Years',
#                'Infant Boy']),
#              ('Fresh Vegetables',
#               ['Onion, Potato & Tomato',
#                'Beans, Brinjal & Bhendi',
#                'Cabbage & Cauliflower',
#                'Cucumber & Capsicum',
#                'Leafy Vegetables',
#                'Gourds, Pumkin & Drumstick',
#                'Root Vegetables',
#                'Other Veg']),
#              ('Cut Vegetables & Salads', ['Cut Vegetables & Salads']),
#              ('Fresh Fruits',
#               ['Apple & Pomegranate',
#                'Banana & Sapota',
#                'Mangoes',
#                'Grapes',
# ...
